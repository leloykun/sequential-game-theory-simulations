# %%
import numpy as np

# %%
res  = np.load('raw/wolfpack_reduction/run_test.npy')[0]
# res = np.concatenate((ar_1to2, ar_3to12, ar_13to22, ar_23to32))
#res = res[:-2]
res
#res.shape
# Out:
# array([[[-3060, -2958],
#         [-1491,  -777],
#         [  777,   -39]],
#
#        [[-3292, -2782],
#         [-1797,    39],
#         [   59,   467]],
#
#        [[-1930, -2950],
#         [-1596,   240],
#         [  104,  -508]],
#
#        [[-2752, -3466],
#         [-1050,  -540],
#         [  749,   953]],
#
#        [[ -569,  -977],
#         [-1224,   714],
#         [  607,   709]],
#
#        [[-3537, -3945],
#         [-2401,   149],
#         [  399,   144]],
#
#        [[-3332, -3230],
#         [ -841,   281],
#         [  627,   525]],
#
#        [[-3003, -3717],
#         [-1374,   -48],
#         [  334,   232]],
#
#        [[-3898, -4714],
#         [-1476,  -252],
#         [  679,  1189]],
#
#        [[-2734, -3142],
#         [-1485,  1167],
#         [  399,   807]],
#
#        [[-5854, -4732],
#         [-2554,  -208],
#         [  776,   572]],
#
#        [[-2206, -3022],
#         [-1911,   435],
#         [   47,   557]],
#
#        [[-1549, -1141],
# ...

# %%
print(np.mean(res, axis=0))
print(np.std(res, axis=0))
# Out:
# [[-2809.65       -2777.35      ]
#  [-1459.28333333    79.21666667]
#  [  535.78333333   669.23333333]]
# [[ 850.14214155  789.13393086]
#  [ 476.7649348   527.69799102]
#  [ 431.25994063  450.56454834]]

# %%
res = np.mean(res, axis=0)
res
# Out:
# array([[-2809.65      , -2777.35      ],
#        [-1459.28333333,    79.21666667],
#        [  535.78333333,   669.23333333]])

# %%
np.interp(res, [np.min(res), np.max(res)], [0, 1])
# Out:
# array([[ 0.        ,  0.00928459],
#        [ 0.38816095,  0.83040056],
#        [ 0.96163999,  1.        ]])
